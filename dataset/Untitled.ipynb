# %%
import pandas as pd
import json

# %%
res = pd.read_json(r"C:\Users\User\Downloads\ubisoft.txt")
res
# Out:
#            Date  Viewer
# 0    2017-01-02   58182
# 1    2017-01-03   27258
# 2    2017-01-04   30013
# 3    2017-01-05   23771
# 4    2017-01-06   42128
# ...         ...     ...
# 1091 2019-12-29   71641
# 1092 2019-12-30   45864
# 1093 2019-12-31   42449
# 1094 2020-01-01   38064
# 1095 2020-01-02   41244
#
# [1096 rows x 2 columns]

# %%
list1 = res['Viewer'].values.tolist()

# %%
list2 = res.Date.dt.strftime('%Y-%m-%d').values.tolist()
type(list2[0])
# Out:
# str

# %%
OAO = {"Date":list2,"Viewers":list1}
OAO
# Out:
# {'Date': ['2017-01-02',
#   '2017-01-03',
#   '2017-01-04',
#   '2017-01-05',
#   '2017-01-06',
#   '2017-01-07',
#   '2017-01-08',
#   '2017-01-09',
#   '2017-01-10',
#   '2017-01-11',
#   '2017-01-12',
#   '2017-01-13',
#   '2017-01-14',
#   '2017-01-15',
#   '2017-01-16',
#   '2017-01-17',
#   '2017-01-18',
#   '2017-01-19',
#   '2017-01-20',
#   '2017-01-21',
#   '2017-01-22',
#   '2017-01-23',
#   '2017-01-24',
#   '2017-01-25',
#   '2017-01-26',
#   '2017-01-27',
#   '2017-01-28',
#   '2017-01-29',
#   '2017-01-30',
#   '2017-01-31',
#   '2017-02-01',
#   '2017-02-02',
#   '2017-02-03',
#   '2017-02-04',
#   '2017-02-05',
#   '2017-02-06',
#   '2017-02-07',
#   '2017-02-08',
#   '2017-02-09',
#   '2017-02-10',
#   '2017-02-11',
#   '2017-02-12',
#   '2017-02-13',
#   '2017-02-14',
#   '2017-02-15',
#   '2017-02-16',
#   '2017-02-17',
#   '2017-02-18',
#   '2017-02-19',
#   '2017-02-20',
#   '2017-02-21',
#   '2017-02-22',
#   '2017-02-23',
#   '2017-02-24',
#   '2017-02-25',
# ...

# %%
st = str(OAO)
str(OAO)
# Out:
# "{'Date': ['2017-01-02', '2017-01-03', '2017-01-04', '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08', '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12', '2017-01-13', '2017-01-14', '2017-01-15', '2017-01-16', '2017-01-17', '2017-01-18', '2017-01-19', '2017-01-20', '2017-01-21', '2017-01-22', '2017-01-23', '2017-01-24', '2017-01-25', '2017-01-26', '2017-01-27', '2017-01-28', '2017-01-29', '2017-01-30', '2017-01-31', '2017-02-01', '2017-02-02', '2017-02-03', '2017-02-04', '2017-02-05', '2017-02-06', '2017-02-07', '2017-02-08', '2017-02-09', '2017-02-10', '2017-02-11', '2017-02-12', '2017-02-13', '2017-02-14', '2017-02-15', '2017-02-16', '2017-02-17', '2017-02-18', '2017-02-19', '2017-02-20', '2017-02-21', '2017-02-22', '2017-02-23', '2017-02-24', '2017-02-25', '2017-02-26', '2017-02-27', '2017-02-28', '2017-03-01', '2017-03-02', '2017-03-03', '2017-03-04', '2017-03-05', '2017-03-06', '2017-03-07', '2017-03-08', '2017-03-09', '2017-03-10', '2017-03-11', '2017-03-12', '2017-0
# ...

# %%
with open("ubisoft_marge.json","w") as fp:
    fp.write(st)
