# %%
import pandas as pd
# f = open(,"r+",)
# data = f.read()
#df = pd.read_csv(r"C:\stockInformationWithOutMining\3659.T.txt")
df = pd.read_csv(r"C:\\Users\\User\\Desktop\\Covid19Tw\\UBI.PA.csv")
# f.close()
df

# %%
df = df.drop(["Open","Low","Close","Adj Close","Volume"],axis = 1)

# %%
list1 = df['High'].values.tolist()
list1
# Out:
# [862.5,
#  867.0,
#  861.5,
#  868.5,
#  867.5,
#  857.5,
#  886.0,
#  877.5,
#  859.0,
#  844.5,
#  857.0,
#  859.5,
#  831.5,
#  830.0,
#  841.5,
#  876.0,
#  885.0,
#  888.0,
#  874.0,
#  876.0,
#  879.0,
#  877.5,
#  887.5,
#  877.0,
#  877.0,
#  888.0,
#  902.5,
#  1013.5,
#  971.5,
#  972.5,
#  972.0,
#  974.0,
#  967.5,
#  961.5,
#  972.5,
#  973.0,
#  972.0,
#  959.0,
#  964.5,
#  960.5,
#  978.0,
#  964.5,
#  976.5,
#  930.5,
#  909.5,
#  894.0,
#  901.0,
#  906.5,
#  896.5,
#  871.5,
#  879.5,
#  880.5,
#  890.0,
#  886.5,
#  871.5,
#  874.5,
#  867.5,
#  870.0,
#  883.5,
#  889.5,
#  898.5,
#  907.0,
#  914.0,
#  914.0,
#  895.0,
#  895.0,
#  898.5,
#  891.5,
#  877.5,
#  857.5,
#  855.0,
#  857.0,
#  863.5,
#  868.0,
#  862.0,
#  858.5,
#  869.5,
#  886.5,
#  938.5,
#  957.0,
#  959.5,
#  968.0,
#  974.5,
#  1009.5,
#  1031.0,
#  1045.5,
#  1052.5,
#  1045.5,
#  1096.0,
#  1100.0,
#  1076.0,
#  1070.5,
#  1055.5,
#  1051.0,
#  1047.0,
#  1062.5,
#  1051.0,
#  1042.5,
# ...

# %%
list2 = df['Date'].values.tolist()
list2
# Out:
# ['2017-01-04',
#  '2017-01-05',
#  '2017-01-06',
#  '2017-01-10',
#  '2017-01-11',
#  '2017-01-12',
#  '2017-01-13',
#  '2017-01-16',
#  '2017-01-17',
#  '2017-01-18',
#  '2017-01-19',
#  '2017-01-20',
#  '2017-01-23',
#  '2017-01-24',
#  '2017-01-25',
#  '2017-01-26',
#  '2017-01-27',
#  '2017-01-30',
#  '2017-01-31',
#  '2017-02-01',
#  '2017-02-02',
#  '2017-02-03',
#  '2017-02-06',
#  '2017-02-07',
#  '2017-02-08',
#  '2017-02-09',
#  '2017-02-10',
#  '2017-02-13',
#  '2017-02-14',
#  '2017-02-15',
#  '2017-02-16',
#  '2017-02-17',
#  '2017-02-20',
#  '2017-02-21',
#  '2017-02-22',
#  '2017-02-23',
#  '2017-02-24',
#  '2017-02-27',
#  '2017-02-28',
#  '2017-03-01',
#  '2017-03-02',
#  '2017-03-03',
#  '2017-03-06',
#  '2017-03-07',
#  '2017-03-08',
#  '2017-03-09',
#  '2017-03-10',
#  '2017-03-13',
#  '2017-03-14',
#  '2017-03-15',
#  '2017-03-16',
#  '2017-03-17',
#  '2017-03-21',
#  '2017-03-22',
#  '2017-03-23',
#  '2017-03-24',
#  '2017-03-27',
#  '2017-03-28',
# ...

# %%
OAO = {"Date":list2,"stockPrice":list1}
OAO
# Out:
# {'Date': ['2017-01-04',
#   '2017-01-05',
#   '2017-01-06',
#   '2017-01-10',
#   '2017-01-11',
#   '2017-01-12',
#   '2017-01-13',
#   '2017-01-16',
#   '2017-01-17',
#   '2017-01-18',
#   '2017-01-19',
#   '2017-01-20',
#   '2017-01-23',
#   '2017-01-24',
#   '2017-01-25',
#   '2017-01-26',
#   '2017-01-27',
#   '2017-01-30',
#   '2017-01-31',
#   '2017-02-01',
#   '2017-02-02',
#   '2017-02-03',
#   '2017-02-06',
#   '2017-02-07',
#   '2017-02-08',
#   '2017-02-09',
#   '2017-02-10',
#   '2017-02-13',
#   '2017-02-14',
#   '2017-02-15',
#   '2017-02-16',
#   '2017-02-17',
#   '2017-02-20',
#   '2017-02-21',
#   '2017-02-22',
#   '2017-02-23',
#   '2017-02-24',
#   '2017-02-27',
#   '2017-02-28',
#   '2017-03-01',
#   '2017-03-02',
#   '2017-03-03',
#   '2017-03-06',
#   '2017-03-07',
#   '2017-03-08',
#   '2017-03-09',
#   '2017-03-10',
#   '2017-03-13',
#   '2017-03-14',
#   '2017-03-15',
#   '2017-03-16',
#   '2017-03-17',
#   '2017-03-21',
#   '2017-03-22',
#   '2017-03-23',
# ...

# %%
with open("Nexon_StockPrice.json","w") as fp:
    fp.write(str(OAO))
